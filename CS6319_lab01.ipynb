# %% [markdown]
# <a href="https://colab.research.google.com/github/ADinng/CS6319_MachineLearning/blob/main/CS6319_lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/telemonitoring/parkinsons_updrs.data")
data.head()
# Out:
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# 4     0.000020     0.00093      0.00130  ...        0.176       0.00679
#
#    Shimmer:APQ5  Shimmer:APQ11  Shimmer:DDA       NHR     HNR     RPDE  \
# ...

# %%
data = data.drop(["subject#","total_UPDRS"], axis=1)

# %%
data.describe()
# Out:
#                age          sex    test_time  motor_UPDRS    Jitter(%)  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     64.804936     0.317787    92.863722    21.296229     0.006154
# std       8.821524     0.465656    53.445602     8.129282     0.005624
# min      36.000000     0.000000    -4.262500     5.037700     0.000830
# 25%      58.000000     0.000000    46.847500    15.000000     0.003580
# 50%      65.000000     0.000000    91.523000    20.871000     0.004900
# 75%      72.000000     1.000000   138.445000    27.596500     0.006800
# max      85.000000     1.000000   215.490000    39.511000     0.099990
#
#        Jitter(Abs)   Jitter:RAP  Jitter:PPQ5   Jitter:DDP      Shimmer  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean      0.000044     0.002987     0.003277     0.008962     0.034035
# std       0.000036     0.003124     0.003732     0.009371     0.025835
# ...

# %%
# creat training and testing data
from sklearn.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size = 0.2)
print(trainset)
print(testset)
# Out:
#       age  sex  test_time  motor_UPDRS  Jitter(%)  Jitter(Abs)  Jitter:RAP  \
# 660    75    0   105.4000      31.4840    0.00444     0.000040     0.00209
# 2578   55    0   137.8300      18.0000    0.01593     0.000129     0.00933
# 1192   73    1   148.5600      21.4860    0.00469     0.000021     0.00212
# 2158   65    0    12.4260       8.8604    0.00793     0.000078     0.00402
# 40     72    0   117.6700      33.1780    0.00806     0.000043     0.00427
# ...   ...  ...        ...          ...        ...          ...         ...
# 1075   73    1    22.5940      18.2460    0.00441     0.000025     0.00180
# 5671   68    1     7.4861      29.6360    0.00672     0.000032     0.00390
# 4225   75    0   174.3600      21.9310    0.00773     0.000064     0.00241
# 4713   71    0   153.5300      35.3750    0.00458     0.000032     0.00210
# 4299   36    1    38.4020      12.9360    0.00371     0.000021     0.00152
#
#       Jitter:PPQ5  Jitter:DDP  Shimmer  Shimmer(dB)  Shimmer:APQ3  \
# ...

# %%
# separate the labels
traindata = trainset.drop("motor_UPDRS", axis=1)
trainlabs = trainset["motor_UPDRS"].copy()

testdata = testset.drop("motor_UPDRS", axis=1)
testlabs = testset["motor_UPDRS"].copy()

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
trainnumr = scaler.fit_transform(traindata)
testnumr = scaler.transform(testdata)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(trainnumr, trainlabs)
# Out:
# LinearRegression()

# %%
test_predictions = linreg.predict(testnumr)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
test_mse = mean_squared_error(testlabs, test_predictions)
test_rmse = np.sqrt(test_mse)
print("The regressor's RMSE err on the test data : ", test_rmse)
# Out:
# The regressor's RMSE err on the test data :  7.618606354695864
